# %%
a = int(input())
for i in range(1,11):
    print(f'{a} x {i} = {a*i}\n')
# Out:
#  7
# 7 x 1 = 7
#
# 7 x 2 = 14
#
# 7 x 3 = 21
#
# 7 x 4 = 28
#
# 7 x 5 = 35
#
# 7 x 6 = 42
#
# 7 x 7 = 49
#
# 7 x 8 = 56
#
# 7 x 9 = 63
#
# 7 x 10 = 70

# %%
h = int(input())
for i in range(1,h+1):
    if i ==1:
        print(" "*(h-1) +"*")
    elif i==h:
        print("*"*(2*h-1))
    else:
        print(" "*(h-i)+"*"+" "*(2*i-3)+"*")
# Out:
#  13
#             *
#            * *
#           *   *
#          *     *
#         *       *
#        *         *
#       *           *
#      *             *
#     *               *
#    *                 *
#   *                   *
#  *                     *
# *************************

# %%
n = int(input())
s=0
k=0
while s<n:
    k+=1
    s+=k

print(s-k)
# Out:
#  7
# 6

# %%
a = int(input())
n=0
s=0
while True:
    n+=1
    s+=1/n
    if s>a:
        break
print(n,s)
# Out:
#  7
# 616 7.001274097134162

# %%
#b14
f=True
while True:
    a = int(input())
    if a==-1:
        break

    if f==True:
        maxs=a
        mins=a
        f = False

    elif f == False:
        if a>maxs:
            maxs=a
        if a<mins:
            mins=a

print(maxs,mins)
# Out:
#  5
#  6
#  7
#  8
#  9
#  45
#  -1
# 45 5

# %%
a = tuple(map(int,input().split()))
k = int(input())
for i in range(0,len(a)):
    while(i+k)<len(a):
        a[i]=a[i+k]
    while(i+k)>=len(a):
# Out:
#   Cell In[28], line 10
#
#     ^
# _IncompleteInputError: incomplete input
